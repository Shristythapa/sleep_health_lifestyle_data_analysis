# %%
path = "D:\Sleep_health_and_lifestyle_dataset.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.DataFrame(pd.read_csv(path))

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83          77         4200           None
# 1           125/80          75        10000           None
# 2           125/80          75        10000           None
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
df.shape
# Out:
# (374, 13)

# %%
df.isnull().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %%
# Descriptive Statistics for quantitative columns
quantitative_columns = ['Age', 'Sleep Duration', 'Heart Rate', 'Daily Steps']
descriptive_stats = df[quantitative_columns].describe()
descriptive_stats
# Out:
#               Age  Sleep Duration  Heart Rate   Daily Steps
# count  374.000000      374.000000  374.000000    374.000000
# mean    42.184492        7.132086   70.165775   6816.844920
# std      8.673133        0.795657    4.135676   1617.915679
# min     27.000000        5.800000   65.000000   3000.000000
# 25%     35.250000        6.400000   68.000000   5600.000000
# 50%     43.000000        7.200000   70.000000   7000.000000
# 75%     50.000000        7.800000   72.000000   8000.000000
# max     59.000000        8.500000   86.000000  10000.000000

# %%
# Distribution of categorical variables
categorical_columns = ['Gender', 'Occupation', 'BMI Category', 'Sleep Disorder']

# Count plot for categorical variables
plt.figure(figsize=(15, 10))

for i, column in enumerate(categorical_columns,1):
    plt.subplot(4, 1, i)
    sns.countplot(data=df, x=column)
    plt.title(f'Distribution of {column}')

plt.tight_layout()
plt.show()

# %%
age_values_male = df[df['Gender'] == 'Male']['Age'].tolist()
age_values_female = df[df['Gender'] == 'Female']['Age'].tolist()


total_male_count = len(age_values_male)
total_female_count = len(age_values_female)


plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.hist(age_values_male, bins=range(min(age_values_male), max(age_values_male) + 1, 1), edgecolor='black', alpha=0.7, label='Male')
plt.title('Male Age Distribution\nTotal Male Count: {}'.format(total_male_count))
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(age_values_female, bins=range(min(age_values_female), max(age_values_female) + 1, 1), edgecolor='black', alpha=0.7, color='orange', label='Female')
plt.title('Female Age Distribution\nTotal Female Count: {}'.format(total_female_count))
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
sleep_duration = df["Sleep Duration"].tolist()
quality_of_sleep=df["Quality of Sleep"].tolist()

# create correlation matrix
matrix = np.corrcoef(sleep_duration, quality_of_sleep)
 
# print matrix
print(matrix)
# Out:
# [[1.       0.883213]
#  [0.883213 1.      ]]

# %%
df.head(10)
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
# 5          6   Male   28     Software Engineer             5.9
# 6          7   Male   29               Teacher             6.3
# 7          8   Male   29                Doctor             7.8
# 8          9   Male   29                Doctor             7.8
# 9         10   Male   29                Doctor             7.8
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
# 5                 4                       30             8        Obese
# 6                 6                       40             7        Obese
# 7                 7                       75             6       Normal
# 8                 7                       75             6       Normal
# 9                 7                       75             6       Normal
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200           None
# 1         125/80          75        10000           None
# 2         125/80          75        10000           None
# 3         140/90          85         3000    Sleep Apnea
# 4         140/90          85         3000    Sleep Apnea
# 5         140/90          85         3000       Insomnia
# 6         140/90          82         3500       Insomnia
# 7         120/80          70         8000           None
# 8         120/80          70         8000           None
# 9         120/80          70         8000           None

# %%
ga= df.groupby(['Gender','Age'])
ga.first()
# Out:
#             Person ID         Occupation  Sleep Duration  Quality of Sleep  \
# Gender Age
# Female 29          17              Nurse             6.5                 5
#        30          31              Nurse             6.4                 5
#        31          33              Nurse             7.9                 8
#        33          69          Scientist             6.2                 6
#        34          81          Scientist             5.8                 4
#        35          86         Accountant             7.2                 8
#        36          95         Accountant             7.2                 8
#        37         107              Nurse             6.1                 6
#        38         128         Accountant             7.1                 8
#        39         149             Lawyer             6.9                 7
#        40         162         Accountant             7.2                 8
#        42         185            Teacher             6.8                 6
#        43         187            Teacher             6.7                 7
#        44         221            Teacher             6.6                 7
#        45         251            Teacher             6.8                 7
#        48         266              Nurse             5.9                 6
#        49         268              Nurse             6.2                 6
#        50         279              Nurse             6.1                 6
#        51         299           Engineer             8.5                 9
#        52         307         Accountant             6.5                 7
#        53         316           Engineer             8.3                 9
#        54         333           Engineer             8.4                 9
#        55         340              Nurse             8.1                 9
#        56         342             Doctor             8.2                 9
#        57         344              Nurse             8.1                 9
#        58         353              Nurse             8.0                 9
#        59         359              Nurse             8.0                 9
# Male   27           1  Software Engineer             6.1                 6
#        28           2             Doctor             6.2                 6
#        29           7            Teacher             6.3                 6
#        30          20             Doctor             7.6                 7
#        31          34             Doctor             6.1                 6
#        32          51           Engineer             7.5                 8
#        33          68             Doctor             6.0                 6
#        35          83            Teacher             6.7                 7
#        36         104            Teacher             6.6                 5
#        37         108           Engineer             7.8                 8
#        38         127             Lawyer             7.3                 8
#        39         147             Lawyer             7.2                 8
#        40         164             Lawyer             7.9                 8
#        41         166             Lawyer             7.6                 8
#        42         178        Salesperson             6.5                 6
#        43         188        Salesperson             6.3                 6
#        44         222        Salesperson             6.4                 6
#        48         265             Doctor             7.3                 7
#        49         277             Doctor             8.1                 9
#
#             Physical Activity Level  Stress Level   BMI Category  \
# Gender Age
# Female 29                        40             7  Normal Weight
#        30                        35             7  Normal Weight
#        31                        75             4  Normal Weight
#        33                        50             6     Overweight
#        34                        32             8     Overweight
#        35                        60             4         Normal
#        36                        60             4         Normal
#        37                        42             6     Overweight
#        38                        60             4         Normal
#        39                        50             6  Normal Weight
#        40                        55             6  Normal Weight
#        42                        45             7     Overweight
#        43                        45             4     Overweight
#        44                        45             4     Overweight
#        45                        30             6     Overweight
#        48                        90             8     Overweight
#        49                        90             8     Overweight
#        50                        90             8     Overweight
#        51                        30             3         Normal
#        52                        45             7     Overweight
#        53                        30             3         Normal
#        54                        30             3         Normal
#        55                        75             4     Overweight
#        56                        90             3  Normal Weight
#        57                        75             3     Overweight
#        58                        75             3     Overweight
#        59                        75             3     Overweight
# Male   27                        42             6     Overweight
#        28                        60             8         Normal
#        29                        40             7          Obese
#        30                        75             6         Normal
#        31                        30             8         Normal
#        32                        45             3         Normal
#        33                        30             8         Normal
#        35                        40             5     Overweight
#        36                        35             7     Overweight
#        37                        70             4  Normal Weight
#        38                        60             5         Normal
#        39                        60             5         Normal
#        40                        90             5         Normal
#        41                        90             5         Normal
#        42                        45             7     Overweight
#        43                        45             7     Overweight
#        44                        45             7     Overweight
#        48                        65             5          Obese
#        49                        85             3          Obese
#
#            Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# Gender Age
# Female 29          132/87          80         4000    Sleep Apnea
#        30          130/86          78         4100    Sleep Apnea
#        31          117/76          69         6800           None
#        33          128/85          76         5500           None
#        34          131/86          81         5200    Sleep Apnea
#        35          115/75          68         7000           None
#        36          115/75          68         7000       Insomnia
#        37          126/83          77         4200           None
#        38          115/75          68         7000           None
#        39          128/85          75         5500           None
#        40          119/77          73         7300           None
#        42          130/85          78         5000    Sleep Apnea
#        43          135/90          65         6000       Insomnia
#        44          135/90          65         6000       Insomnia
#        45          135/90          65         6000       Insomnia
#        48          140/95          75        10000    Sleep Apnea
#        49          140/95          75        10000           None
#        50          140/95          75        10000       Insomnia
#        51          125/80          65         5000           None
#        52          130/85          72         6000       Insomnia
#        53          125/80          65         5000       Insomnia
#        54          125/80          65         5000           None
#        55          140/95          72         5000    Sleep Apnea
#        56          118/75          65        10000           None
#        57          140/95          68         7000           None
#        58          140/95          68         7000    Sleep Apnea
#        59          140/95          68         7000           None
# Male   27          126/83          77         4200           None
#        28          125/80          75        10000           None
#        29          140/90          82         3500       Insomnia
#        30          120/80          70         8000           None
#        31          125/80          72         5000           None
#        32          120/80          70         8000           None
#        33          125/80          72         5000       Insomnia
#        35          128/84          70         5600           None
#        36          129/84          74         4800    Sleep Apnea
#        37          120/80          68         7000           None
#        38          130/85          68         8000           None
#        39          130/85          68         8000       Insomnia
#        40          130/85          68         8000           None
#        41          130/85          70         8000       Insomnia
#        42          130/85          72         6000       Insomnia
#        43          130/85          72         6000       Insomnia
#        44          130/85          72         6000       Insomnia
#        48          142/92          83         3500       Insomnia
#        49          139/91          86         3700    Sleep Apnea

# %%
# Group by 'Gender' and calculate the correlation coefficient
correlation_matrix = df.groupby('Gender').apply(lambda x: x['Sleep Duration'].corr(x['Quality of Sleep'])).dropna()
print(correlation_matrix)

values=df.groupby('Gender').first()[['Sleep Duration','Quality of Sleep']]
print(values)
# Out:
# Gender
# Female    0.943502
# Male      0.812399
# dtype: float64
#         Sleep Duration  Quality of Sleep
# Gender
# Female             6.5                 5
# Male               6.1                 6

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83          77         4200           None
# 1           125/80          75        10000           None
# 2           125/80          75        10000           None
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %%
correlation_matrix=df[['Age','Sleep Duration','Quality of Sleep','Physical Activity Level','Stress Level','Heart Rate','Daily Steps']].corr()

# %%
# Plotting the heatmap
plt.figure(figsize=(5, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.1)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# High correlation notable
# 1. Age and quality of sleep
# 2. Quality of sleep and sleep duration
# 3. Heart rate and stress level
# 4. Age and physical activity
# 5. Quality of sleep and physical activity level
#
# Low correlation notable
# 1. Stress level and quality of sleep
# 2. Age and stress level

# %%
#dividing age group
df['Age Group']='Person'
df.loc[df['Age']<40,'Age Group']='Young Audlt'
df.loc[df['Age']<60,'Age Group']='Audlt'
df.loc[df['Age']<39,'Age Group']='Old age'

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder Age Group
# 0           126/83          77         4200           None   Old age
# 1           125/80          75        10000           None   Old age
# 2           125/80          75        10000           None   Old age
# 3           140/90          85         3000    Sleep Apnea   Old age
# 4           140/90          85         3000    Sleep Apnea   Old age
# ..             ...         ...          ...            ...       ...
# 369         140/95          68         7000    Sleep Apnea     Audlt
# 370         140/95          68         7000    Sleep Apnea     Audlt
# 371         140/95          68         7000    Sleep Apnea     Audlt
# 372         140/95          68         7000    Sleep Apnea     Audlt
# 373         140/95          68         7000    Sleep Apnea     Audlt
#
# [374 rows x 14 columns]

# %%
plot_variables = ['Age','Quality of Sleep','Physical Activity Level','Stress Level','Heart Rate']

sns.pairplot(df[plot_variables], diag_kind='kde',hue='Age',palette="crest")

# %%
plt.scatter(df[df['Gender']=='Male']['Physical Activity Level'],df[df['Gender']=='Male']['Quality of Sleep'],color='b',label='Male',alpha=0.5)
plt.scatter(df[df['Gender']=='Female']['Physical Activity Level'],df[df['Gender']=='Female']['Quality of Sleep'],color='pink',label='Female',alpha=0.5)

# Add labels and title
plt.xlabel('Physical Activity Level')
plt.ylabel('Quality of Sleep')
plt.title('Scatter Plot')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define a dictionary for colors
category_colors = {'Male': 'b', 'Female': 'pink'}

# Loop through categories and plot
for category, color in category_colors.items():
    subset = df[df['Gender'] == category]
    plt.scatter(subset['Physical Activity Level'], subset['Quality of Sleep'], color=color, label=category, alpha=0.5)

# Add labels and title
plt.xlabel('Physical Activity Level')
plt.ylabel('Quality of Sleep')
plt.title('Scatter Plot')
plt.legend()

# Show the plot
plt.show()
