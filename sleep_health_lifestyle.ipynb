# %%
pip install jupyter_contrib_nbextensions
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
path = "D:\Sleep_health_and_lifestyle_dataset.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(pd.read_csv(path))

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
df.shape
# Out:
# (374, 13)

# %%
df.isnull().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %%
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
print(df['Gender'].value_counts())
# Out:
# Male      189
# Female    185
# Name: Gender, dtype: int64

# %%
gender_counts = df['Gender'].value_counts()


plt.figure(figsize=(8, 6))
gender_counts.plot(kind='bar', color=['blue', 'pink']) 
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0) 
plt.show()

# %%
age_counts = df["Age"].value_counts()

plt.figure(figsize=(10, 6))
plt.hist(age_counts.index, bins=len(age_counts), weights=age_counts, edgecolor='black', alpha=0.7)
plt.title('Age Value Count Histogram')
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
age_values_male = df[df['Gender'] == 'Male']['Age'].tolist()
age_values_female = df[df['Gender'] == 'Female']['Age'].tolist()


total_male_count = len(age_values_male)
total_female_count = len(age_values_female)


plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.hist(age_values_male, bins=range(min(age_values_male), max(age_values_male) + 1, 1), edgecolor='black', alpha=0.7, label='Male')
plt.title('Male Age Distribution\nTotal Male Count: {}'.format(total_male_count))
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(age_values_female, bins=range(min(age_values_female), max(age_values_female) + 1, 1), edgecolor='black', alpha=0.7, color='orange', label='Female')
plt.title('Female Age Distribution\nTotal Female Count: {}'.format(total_female_count))
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
sleep_duration =  df['Sleep Duration'].tolist() 
quality_of_sleep =  df['Quality of Sleep'].tolist() 


plt.figure(figsize=(8, 6))
plt.plot(sleep_duration, marker='o', label='Sleep Duration', color='blue', linewidth=2)
plt.plot(quality_of_sleep, marker='o', label='Quality of Sleep', color='green', linewidth=2)
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.title('Sleep Duration and Quality of Sleep')
plt.legend()
plt.grid(True)
plt.show()

# %%
df.corr()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10280\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                          Person ID       Age  Sleep Duration  \
# Person ID                 1.000000  0.990516        0.296305
# Age                       0.990516  1.000000        0.344709
# Sleep Duration            0.296305  0.344709        1.000000
# Quality of Sleep          0.431612  0.473734        0.883213
# Physical Activity Level   0.149882  0.178993        0.212360
# Stress Level             -0.394287 -0.422344       -0.811023
# Heart Rate               -0.225467 -0.225606       -0.516455
# Daily Steps               0.043844  0.057973       -0.039533
#
#                          Quality of Sleep  Physical Activity Level  \
# ...
